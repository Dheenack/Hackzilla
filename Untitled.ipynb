# %%
import pandas as pd

# %% [markdown]
# # train data

# %%
dt=pd.read_csv("training_data.csv")

# %%
dt.head().T
# Out:
#                            0             1             2             3  \
# Age                     32.0          45.0          38.0          37.0
# Decision_Class           1.0           1.0           1.0           1.0
# Gender                     f             f             f             m
# Hb                      10.9           9.6          10.1          11.0
# MCH                     25.5          26.4          27.4          27.9
# MCHC                    31.8          32.2          31.3          32.7
# MCV                     80.2          82.1          87.6          85.3
# PCV                     34.2          29.9          32.4          33.6
# Platelet                 NaN           NaN           NaN           NaN
# RBC                     4.26          3.64           3.7          3.93
# RDW                      NaN           NaN           NaN           NaN
# SNo                      NaN           NaN           NaN           NaN
# ...

# %%
dt.tail()
# Out:
#         Age  Decision_Class Gender    Hb   MCH  MCHC   MCV   PCV Platelet  \
# 11617  17.0             NaN    0.0  13.5  27.7  34.4  80.7  39.2    180.0
# 11618  51.0             NaN    0.0  15.0  31.0  33.8  91.7  35.2    215.0
# 11619  21.0             NaN    1.0  13.1  29.3  33.0  88.7  39.7    329.0
# 11620  35.0             NaN    1.0  13.2  27.9  32.1  86.7  36.2    174.0
# 11621  26.0             NaN    0.0  15.2  30.6  34.2  89.7  44.4    279.0
#
#         RBC   RDW    SNo   TLC  Unnamed: 0   source
# 11617  4.86  13.4  360.0   4.4       360.0  anemia6
# 11618  4.85  13.3  361.0   5.6       361.0  anemia6
# 11619  4.47  13.5  362.0   9.2       362.0  anemia6
# 11620  4.75  13.5  363.0  6.48       363.0  anemia6
# 11621  4.95  12.3  364.0   8.8       364.0  anemia6

# %%
dt.shape
# Out:
# (11622, 15)

# %%
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# # EDA

# %%
df=
# Out:
#                Age  Decision_Class          MCHC         SNo  Unnamed: 0
# count  1700.000000    10892.000000  11620.000000  728.000000  364.000000
# mean     42.631176        0.379820     33.395995  182.500000  182.500000
# std      17.365505        0.485364      1.874977  105.149595  105.221988
# min      11.000000        0.000000     23.600000    1.000000    1.000000
# 25%      28.000000        0.000000     32.700000   91.750000   91.750000
# 50%      40.000000        0.000000     33.700000  182.500000  182.500000
# 75%      57.000000        1.000000     34.500000  273.250000  273.250000
# max      96.000000        1.000000     69.600000  364.000000  364.000000
